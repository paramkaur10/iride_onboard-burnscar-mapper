# %% [markdown]
# # IRIDE Burnt-Area Segmentation — NAS Training
#
# This notebook orchestrates the full Neural Architecture Search (NAS) pipeline
# for on-board burnt-area detection on the IRIDE constellation.
#
# ## Overview
#
# The pipeline has **three stages**:
#
# | Stage | What happens | Scope |
# |-------|-------------|-------|
# | **NAS search** | 50 architectures × 3 generations = 150 candidate models trained on an 8 k-tile stratified subset | Fast per-candidate evaluation |
# | **FP32 fine-tune** | Best architecture re-trained from scratch on the full 50 k-tile dataset | Full accuracy |
# | **FP16-aware fine-tune** | FP32 weights loaded, FP16 simulation applied for 15 more epochs | Myriad X deployment |
#
# ## Two saved models per candidate (and for the final winner)
#
# - `model_fp32.pt` — standard FP32 weights → **ground-station / GPU deployment**
# - `model_fp16aware.pt` — weights rounded to IEEE FP16 precision via forward hooks
#   (STE gradient) → **Myriad X on-board deployment** (no hardware needed to produce this)
#
# ## Hardware target
#
# Myriad X executes inference in IEEE 754 half precision.  Our FP16-aware training
# simulates exactly this by rounding weights and activations to FP16 after each
# Conv2d / Linear layer, while keeping gradients in FP32 (straight-through
# estimator).  No OpenVINO export or physical device is required to produce a
# Myriad-X-compatible model — the `.pt` file contains FP16-rounded weights that
# are directly deployable.
#
# ## Dataset
#
# 88 112 tiles (82 GB) across:
# - `train` / `val` / `test`       — PhiSat-2 simulated, scene-level split 80/10/10
# - `heo_train` / `heo_val` / `heo_test` — real HEO acquisitions, held for fine-tuning
#
# Class legend (7 classes including nodata):
# ```
# 0  clear          →  train ID 0
# 2  fresh burn     →  train ID 1   (≤90 days since fire — S4-08 target class)
# 3  old burn       →  train ID 2
# 4  cloud          →  train ID 3
# 5  cloud shadow   →  train ID 4
# 6  water          →  train ID 5
# 255 nodata        →  -1  (ignored by loss)
# ```

# %% [markdown]
# ---
# ## Cell 1 — Notebook setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"  # must be before ANY torch import
print("CUDA_LAUNCH_BLOCKING set to 1")
# Out:
# CUDA_LAUNCH_BLOCKING set to 1

# %% [markdown]
# ## Cell 2 — Environment check
#
# Confirm GPU availability and PyNAS version before doing anything else.
# You should see 2× NVIDIA A30-24C GPUs.

# %%
import torch
import pynas

print("PyNAS version :", pynas.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version  :", torch.version.cuda)
print("GPU count     :", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    print(f"  GPU {i}:", torch.cuda.get_device_name(i))
# Out:
# PyNAS version : 0.1.0
# CUDA available: True
# CUDA version  : 13.0
# GPU count     : 2
#   GPU 0: NVIDIA A30-24C
#   GPU 1: NVIDIA A30-24C

# %% [markdown]
# ## Cell 3 — Imports
#
# All project-local modules (`preprocessing`, `dataset`) must exist in the
# project root before this cell runs.  They are written by the training setup
# and should already be on disk at:
# ```
# ~/projects/iride_onboard-burnscar-mapper/preprocessing.py
# ~/projects/iride_onboard-burnscar-mapper/dataset.py
# ```

# %%
import sys, os, copy, json
import numpy as np
import pandas as pd
from pathlib import Path

# ── project root on sys.path so local modules resolve ────────────────────────
PROJECT_ROOT = os.path.expanduser("~/projects/iride_onboard-burnscar-mapper")
os.chdir(PROJECT_ROOT)
sys.path.insert(0, PROJECT_ROOT)          # preprocessing.py, dataset.py
sys.path.insert(0, f"{PROJECT_ROOT}/pyqnas/src")  # pynas package

import torch
import torch.nn as nn
import pytorch_lightning as pl
from torch.utils.data import WeightedRandomSampler

from pynas.core.config import load_default_config, default_config_path
from pynas.core.population import Population
from pynas.core.generic_lightning_module import GenericLightningSegmentationNetwork
from pynas.core.qat_utils import read_fp16aware_opts, prepare_fp16_aware

# local project modules (must exist in PROJECT_ROOT)
from preprocessing import (
    to_reflectance,
    remap_mask_to_train_ids,
    train_augment,
    eval_transform,
    N_CLASSES,
    QUANTIFICATION,
)
from dataset import TileDataset

print("all imports OK")
print("config path  :", default_config_path())
# Out:
# all imports OK
# config path  : /root/projects/iride_onboard-burnscar-mapper/pyqnas/src/pynas/core/config.ini

# %% [markdown]
# ## Cell 4 — Load and verify the rewritten config
#
# The config at `pyqnas/src/pynas/core/config.ini` was rewritten for this project:
# - `[GA] population_size = 50` (50 models per generation)
# - `[GA] max_iterations  = 3`  (3 generations → 150 total)
# - `[Precision] train = fp32, fp16` (two training stages only, no INT8)
# - `[Precision] fitness = fp16` (NAS selection driven by FP16-sim IoU)
# - `[Myriad] enabled = false` (no hardware; GPU-only evaluation)
#
# If any assertion fails, the config file was not written correctly.

# %%
config = load_default_config()

assert config.getint("GA", "population_size") == 50, \
    f"expected population_size=50, got {config.getint('GA','population_size')}"
assert config.getint("GA", "max_iterations")  == 3, \
    f"expected max_iterations=3, got {config.getint('GA','max_iterations')}"
assert config.getint("GA", "max_parameters")  == 3_000_000
assert config.get("Precision", "train").replace(" ", "") == "fp32,fp16"
assert config.get("Precision", "fitness") == "fp16"
assert not config.getboolean("Myriad", "enabled"), \
    "Myriad must be disabled — no hardware available"

print("Config verified ✓")
print(f"  population_size : {config.getint('GA', 'population_size')}")
print(f"  max_iterations  : {config.getint('GA', 'max_iterations')}")
print(f"  max_parameters  : {config.getint('GA', 'max_parameters'):,}  (= 6 MB at FP16)")
print(f"  fp32_epochs     : {config.getint('Precision', 'fp32_epochs')}")
print(f"  fp16_epochs     : {config.getint('QAT', 'finetune_epochs')}")
print(f"  train precisions: {config.get('Precision', 'train')}")
print(f"  fitness         : {config.get('Precision', 'fitness')}")
print(f"  myriad enabled  : {config.getboolean('Myriad', 'enabled')}")
# Out:
# Config verified ✓
#   population_size : 50
#   max_iterations  : 3
#   max_parameters  : 3,000,000  (= 6 MB at FP16)
#   fp32_epochs     : 12
#   fp16_epochs     : 12
#   train precisions: fp32, fp16
#   fitness         : fp16
#   myriad enabled  : False

# %% [markdown]
# ## Cell 5 — Constants
#
# All tunable numbers come from the config so the notebook never needs editing
# to change run parameters — edit `config.ini` instead.

# %%
# ── Reproducibility ───────────────────────────────────────────────────────────
pl.seed_everything(seed=config.getint("Computation", "seed"), workers=True)
torch.set_float32_matmul_precision("medium")  # speeds up matmul on A30 with no IoU impact

# ── NAS / GA hyper-parameters ────────────────────────────────────────────────
MAX_LAYERS    = config.getint("NAS",    "max_layers",      fallback=7)
N_INDIVIDUALS = config.getint("GA",     "population_size")
K_BEST        = config.getint("GA",     "k_best")
N_RANDOM      = config.getint("GA",     "n_random")
POOL_CUTOFF   = config.getfloat("GA",   "mating_pool_cutoff")
MUTATION_P    = config.getfloat("GA",   "mutation_probability")
MAX_ITER      = config.getint("GA",     "max_iterations")
BATCH_SIZE    = config.getint("GA",     "batch_size")
MAX_PARAMS    = config.getint("GA",     "max_parameters")

# ── Training epochs ──────────────────────────────────────────────────────────
FP32_EPOCHS   = config.getint("Precision", "fp32_epochs")
FP16_EPOCHS   = config.getint("QAT",       "finetune_epochs")

# ── Optimiser ────────────────────────────────────────────────────────────────
LR            = 10 ** config.getfloat("Search Space", "default_log_lr", fallback=-3.0)

# ── Dataset ──────────────────────────────────────────────────────────────────
N_BANDS       = 7
TILE_SIZE     = 256
TILES_ROOT    = "processed/dataset_v1"
INDEX_CSV     = f"{TILES_ROOT}/tiles_index.csv"
SAVE_DIR      = "models_traced"
NAS_SUBSET_N  = 8_000   # tiles used for NAS search evaluation (full = ~50 k)

# ── Class weights for cross-entropy loss ─────────────────────────────────────
# Derived from dataset_stats_summary.csv (Cell 9 of the stats notebook).
# Inverse pixel frequency, normalised to sum to 1.
# clear=66%  fresh=15%  old=6.5%  cloud=0.4%  shadow=0.1%  water=11%
CLASS_PIXEL_FREQS = np.array([0.661, 0.154, 0.065, 0.004, 0.001, 0.110])
CLASS_WEIGHTS = torch.from_numpy(
    (1.0 / np.maximum(CLASS_PIXEL_FREQS, 1e-4)) /
    (1.0 / np.maximum(CLASS_PIXEL_FREQS, 1e-4)).sum()
).float()

print("Class weights:")
for name, w in zip(["clear","fresh_burn","old_burn","cloud","cloud_shadow","water"],
                    CLASS_WEIGHTS.tolist()):
    print(f"  {name:<14}: {w:.4f}")
# Out:
# Seed set to 42
# Class weights:
#   clear         : 0.0012
#   fresh_burn    : 0.0051
#   old_burn      : 0.0120
#   cloud         : 0.1949
#   cloud_shadow  : 0.7797
#   water         : 0.0071

# %% [markdown]
# ## Cell 6 — DataModule
#
# `BalancedTileDataModule` replaces the zarr-based `SegmentationDataModule`
# from the original py-q-nas notebook.
#
# Key design choices:
# - **Weighted tile sampler at train time**: each tile's sampling probability
#   is proportional to its rarest-class pixel fraction (fresh/old burn, cloud,
#   shadow, water).  Pure-clear tiles get a floor weight of 0.02 so they're
#   never completely absent.  This means the model sees burn/cloud examples
#   far more often than their 6–15% pixel share would normally allow.
# - **NAS subset mode** (`nas_subset_n`): for the search phase, a stratified
#   8 k-tile subset is used so each candidate trains in minutes rather than
#   hours.  All informative tiles are included; clear tiles fill the remainder.
# - **Full dataset mode** (`nas_subset_n=None`): used for final winner
#   retraining after the search completes.
#
# The datamodule exposes `input_shape` and `num_classes` which are read by
# `Population.build_model` to construct the right network head.

# %%
class BalancedTileDataModule(pl.LightningDataModule):
    def __init__(self, tiles_root, index_csv, batch_size=16, num_workers=4,
                 nas_subset_n=None, seed=42):
        super().__init__()
        self.root        = tiles_root
        self.index_csv   = index_csv
        self.batch_size  = batch_size
        self.num_workers = num_workers
        self.nas_n       = nas_subset_n
        self.seed        = seed
        # read by Population.build_model to construct network input/output
        self.input_shape = (N_BANDS, TILE_SIZE, TILE_SIZE)
        self.num_classes = N_CLASSES

    def setup(self, stage=None):
        idx   = pd.read_csv(self.index_csv)
        train = idx[(idx.split == "train") & (idx.gsd == "native")].reset_index(drop=True)
        val   = idx[(idx.split == "val")   & (idx.gsd == "native")].reset_index(drop=True)
        test  = idx[(idx.split == "test")  & (idx.gsd == "native")].reset_index(drop=True)

        if self.nas_n is not None:
            rng     = np.random.default_rng(self.seed)
            inf_idx = train[train.informative].index.tolist()
            clr_idx = train[~train.informative].index.tolist()
            n_clr   = max(0, self.nas_n - len(inf_idx))
            chosen  = rng.choice(clr_idx, size=min(n_clr, len(clr_idx)),
                                 replace=False).tolist()
            train   = train.loc[inf_idx + chosen].reset_index(drop=True)
            print(f"NAS subset: {len(train):,} tiles "
                  f"({len(inf_idx):,} informative + {len(chosen):,} clear)")

        self.train_ds = TileDataset(self.root, train, is_train=True)
        self.val_ds   = TileDataset(self.root, val,   is_train=False)
        self.test_ds  = TileDataset(self.root, test,  is_train=False)

        # tile sampling weight = combined rare-class pixel fraction, floor 0.02
        rare = (train.get("frac_2", 0) + train.get("frac_3", 0) +
                train.get("frac_4", 0) + train.get("frac_5", 0)).values
        w = np.maximum(rare, 0.02).astype(np.float64)
        w /= w.sum()
        self._sampler = WeightedRandomSampler(
            torch.from_numpy(w).float(), len(self.train_ds), replacement=True)

    def train_dataloader(self):
        return torch.utils.data.DataLoader(
            self.train_ds, batch_size=self.batch_size, sampler=self._sampler,
            num_workers=self.num_workers, pin_memory=True, drop_last=True)

    def val_dataloader(self):
        return torch.utils.data.DataLoader(
            self.val_ds, batch_size=self.batch_size, shuffle=False,
            num_workers=self.num_workers, pin_memory=True)

    def test_dataloader(self):
        return torch.utils.data.DataLoader(
            self.test_ds, batch_size=self.batch_size, shuffle=False,
            num_workers=self.num_workers, pin_memory=True)

# %% [markdown]
# ## Cell 7 — Sanity check
#
# Verify the datamodule, tile shapes, reflectance range, and mask values
# before spending any GPU time.  **Do not proceed to Cell 9 if this fails.**

# %%
dm_nas = BalancedTileDataModule(
    TILES_ROOT, INDEX_CSV,
    batch_size=BATCH_SIZE, num_workers=4,
    nas_subset_n=NAS_SUBSET_N,
)
dm_nas.setup()

img, mask = next(iter(dm_nas.train_dataloader()))

print(f"img  shape : {tuple(img.shape)}   dtype: {img.dtype}")
print(f"mask shape : {tuple(mask.shape)}  dtype: {mask.dtype}")
print(f"img  range : [{img.min():.4f}, {img.max():.4f}]  (expect ~[0, 1])")
print(f"mask values: {sorted(mask.unique().tolist())}  (expect subset of {{-1,0,1,2,3,4,5}})")
print(f"train tiles: {len(dm_nas.train_ds):,}   val: {len(dm_nas.val_ds):,}   test: {len(dm_nas.test_ds):,}")

assert tuple(img.shape[1:]) == (N_BANDS, TILE_SIZE, TILE_SIZE), \
    f"expected ({N_BANDS},{TILE_SIZE},{TILE_SIZE}), got {tuple(img.shape[1:])}"
assert img.max() <= 1.01,  "reflectance > 1.0 — normalisation bug in preprocessing.py"
assert img.min() >= -0.01, "reflectance < 0.0 — normalisation bug in preprocessing.py"
assert set(mask.unique().tolist()) <= set(range(-1, N_CLASSES)), \
    f"unexpected mask values: {mask.unique().tolist()}"

print("\n✓ Sanity check passed — safe to proceed to NAS search")
# Out:
# NAS subset: 31,937 tiles (31,937 informative + 0 clear)
# img  shape : (8, 7, 256, 256)   dtype: torch.float32
# mask shape : (8, 256, 256)  dtype: torch.int64
# img  range : [0.0000, 1.0000]  (expect ~[0, 1])
# mask values: [-1, 0, 1, 2]  (expect subset of {-1,0,1,2,3,4,5})
# train tiles: 31,937   val: 6,367   test: 5,865
#
# ✓ Sanity check passed — safe to proceed to NAS search

# %% [markdown]
# ## Cell 8 — Two-scenario training function
#
# This function replaces `pop.train_generation()` from the original notebook.
# The original ran 6 scenarios (3 GPU + 3 Myriad) per candidate.
# We run exactly **2** (both GPU-only):
#
# 1. **FP32** — trains from random init for `fp32_epochs`.
#    Saves `model_fp32.pt` → ground/GPU deployment.
#
# 2. **FP16-aware finetune** — loads FP32 weights, applies `prepare_fp16_aware`
#    (registers STE hooks on Conv2d/Linear to round activations/weights to
#    IEEE FP16 each forward pass), trains for `fp16_epochs` at 0.1× LR.
#    Saves `model_fp16aware.pt` → Myriad X deployment.
#
# Fitness = α · fp16_iou + β · min(fps / fps_target, 1)
# with α=1.0, β=0.2, fps_target=30  (same as [Fitness] section of config).

# %%
# ── Cell 8 — Two-scenario training function ──────────────────────────────────
#
# Replaces pop.train_generation() from the original py-q-nas notebook.
# Runs exactly TWO GPU-only scenarios per candidate:
#
#   Scenario 1 — FP32 from scratch
#     Full training for fp32_epochs. Saves model_fp32.pt.
#     Target: ground station / GPU deployment.
#
#   Scenario 2 — FP16-aware fine-tune from FP32
#     Loads FP32 weights, attaches STE-based FP16 rounding hooks to every
#     Conv2d and Linear layer (IEEE 754 half precision, forward-only),
#     trains for fp16_epochs at 0.1× LR. Saves model_fp16aware.pt.
#     Target: Myriad X on-board deployment (no hardware required to produce).
#
#   Fitness = α·fp16_iou + β·min(fps / fps_target, 1)
#   with α=1.0  β=0.2  fps_target=30  (matches [Fitness] section of config)
#
# Robustness features:
#   - CUDA context is synchronised and cache-cleared after every failure so a
#     single OOM or assert cannot poison subsequent candidates in the same run.
#   - All results written to metrics.json + pop.df immediately, so a kernel
#     restart never loses a completed candidate.
# ─────────────────────────────────────────────────────────────────────────────

def free_vram_gb(device=0):
    """Returns free VRAM in GB on the given CUDA device."""
    if not torch.cuda.is_available():
        return 0.0
    torch.cuda.synchronize(device)
    free, _ = torch.cuda.mem_get_info(device)
    return free / 1e9


MIN_FREE_VRAM_GB = 4.0   # skip candidate if less than this is available


def _reset_cuda():
    """Best-effort CUDA context flush after a failure."""
    try:
        torch.cuda.synchronize()
        torch.cuda.empty_cache()
    except Exception:
        pass
    try:
        import gc; gc.collect()
    except Exception:
        pass


def train_two_scenarios(
    pop,
    idx,
    dm,
    lr=None,
    fp32_epochs=None,
    fp16_epochs=None,
):
    """
    Train one NAS candidate through FP32 + FP16-aware scenarios.

    Parameters
    ----------
    pop         : Population  — the active NAS population object
    idx         : int         — index into pop.population
    dm          : LightningDataModule — provides train/val/test dataloaders
    lr          : float | None — base learning rate; defaults to LR from Cell 5
    fp32_epochs : int | None  — overrides FP32_EPOCHS (use for final retraining)
    fp16_epochs : int | None  — overrides FP16_EPOCHS (use for final retraining)

    Returns
    -------
    dict with keys fp32_iou, fp32_fps, fp16_iou, fp16_fps, fitness, or None on failure.
    """
    # resolve defaults from outer scope (Cell 5 constants)
    _lr          = lr          if lr          is not None else LR
    _fp32_epochs = fp32_epochs if fp32_epochs is not None else FP32_EPOCHS
    _fp16_epochs = fp16_epochs if fp16_epochs is not None else FP16_EPOCHS

    individual = pop.population[idx]
    gen        = pop.generation
    gen_dir    = Path(SAVE_DIR) / f"generation_{gen}" / f"model_{idx}"
    gen_dir.mkdir(parents=True, exist_ok=True)

    # class-weighted loss; ignore_index=-1 keeps nodata pixels out of the gradient
    loss_fn = nn.CrossEntropyLoss(
        weight     = CLASS_WEIGHTS.to(torch.float32).cuda(),
        ignore_index = -1,
        reduction  = "mean",
    )

    # ── VRAM pre-check ────────────────────────────────────────────────────
    free = free_vram_gb(0)
    if free < MIN_FREE_VRAM_GB:
        _reset_cuda()
        free = free_vram_gb(0)
    if free < MIN_FREE_VRAM_GB:
        print(f"  [{idx:02d}] only {free:.1f} GB free — skipping "
              f"(will be retried next resume)")
        return None

    # ═════════════════════════════════════════════════════════════════════
    # Scenario 1 — FP32
    # ═════════════════════════════════════════════════════════════════════
    print(f"  [{idx:02d}] Scenario 1: FP32  ({_fp32_epochs} epochs, lr={_lr:.2e})")
    try:
        model, valid = pop.build_model(
            individual.parsed_layers, task="segmentation")
        if not valid:
            print(f"  [{idx:02d}] build_model returned invalid — skipping")
            individual.fitness = 0.0
            return None

        LM         = GenericLightningSegmentationNetwork(
            model=model, learning_rate=_lr)
        LM.loss_fn = loss_fn

        trainer = pl.Trainer(
            max_epochs              = _fp32_epochs,
            accelerator             = "gpu",
            devices                 = 1,
            accumulate_grad_batches = 2,      # effective batch = NAS_BATCH_SIZE×2
            logger                  = False,
            
            enable_checkpointing    = False,
            enable_progress_bar     = False,   # ← turn off per-step bar
            log_every_n_steps       = 999,     # ← suppress step-level logging
            callbacks               = [], 
        )
        trainer.fit(LM, dm)
        res_fp32  = trainer.test(LM, dm, verbose=False)[0]
        fp32_iou  = float(res_fp32.get("test_iou",
                          res_fp32.get("test_iou_epoch", 0.0)))
        fp32_fps  = float(res_fp32.get("test_fps", 1.0))

        # save FP32 weights and keep a CPU copy for FP16 init
        torch.save(LM.model.state_dict(), gen_dir / "model_fp32.pt")
        fp32_state = {k: v.cpu().clone() for k, v in LM.model.state_dict().items()}
        print(f"  [{idx:02d}] FP32  → IoU={fp32_iou:.4f}  FPS={fp32_fps:.1f}")

        # free GPU memory before building the FP16 model
        del LM, trainer, model
        _reset_cuda()

    except torch.cuda.OutOfMemoryError:
        print(f"  [{idx:02d}] FP32 OOM — skipping (increase accumulate_grad_batches)")
        individual.fitness = 0.0
        _reset_cuda()
        return None
    except Exception as e:
        print(f"  [{idx:02d}] FP32 FAILED: {e}")
        individual.fitness = 0.0
        _reset_cuda()
        return None

    # ═════════════════════════════════════════════════════════════════════
    # Scenario 2 — FP16-aware fine-tune
    # ═════════════════════════════════════════════════════════════════════
    print(f"  [{idx:02d}] Scenario 2: FP16-aware "
          f"({_fp16_epochs} epochs, lr={_lr*0.1:.2e})")
    try:
        fp16_opts = read_fp16aware_opts(config)
        fp16_opts.finetune_epochs = _fp16_epochs

        # fresh model instance; load FP32 weights; attach FP16 simulation hooks
        model_ft, _ = pop.build_model(
            individual.parsed_layers, task="segmentation")
        model_ft.load_state_dict(fp32_state)
        ctx = prepare_fp16_aware(model_ft, fp16_opts)

        LM_ft         = GenericLightningSegmentationNetwork(
            model=model_ft, learning_rate=_lr * 0.1)
        LM_ft.loss_fn = loss_fn

        trainer_ft = pl.Trainer(
            max_epochs              = _fp16_epochs,
            accelerator             = "gpu",
            devices                 = 1,
            accumulate_grad_batches = 2,
            logger                  = False,
              enable_checkpointing    = False,
            enable_progress_bar     = False,   # ← turn off per-step bar
            log_every_n_steps       = 999,     # ← suppress step-level logging
            callbacks               = [], 
        )
        trainer_ft.fit(LM_ft, dm)
        res_fp16  = trainer_ft.test(LM_ft, dm, verbose=False)[0]
        fp16_iou  = float(res_fp16.get("test_iou",
                          res_fp16.get("test_iou_epoch", 0.0)))
        fp16_fps  = float(res_fp16.get("test_fps", 1.0))

        torch.save(LM_ft.model.state_dict(), gen_dir / "model_fp16aware.pt")
        ctx.close()   # detach STE hooks and weight parametrizations cleanly
        print(f"  [{idx:02d}] FP16  → IoU={fp16_iou:.4f}  FPS={fp16_fps:.1f}")

        del LM_ft, trainer_ft, model_ft
        _reset_cuda()

    except torch.cuda.OutOfMemoryError:
        print(f"  [{idx:02d}] FP16 OOM — saving FP32 only, fitness=fp32_iou")
        fp16_iou, fp16_fps = fp32_iou * 0.95, fp32_fps  # penalised estimate
        _reset_cuda()
    except Exception as e:
        print(f"  [{idx:02d}] FP16 FAILED: {e} — saving FP32 only")
        fp16_iou, fp16_fps = fp32_iou * 0.95, fp32_fps
        _reset_cuda()

    # ═════════════════════════════════════════════════════════════════════
    # Fitness + bookkeeping
    # ═════════════════════════════════════════════════════════════════════
    alpha, beta, fps_target = 1.0, 0.2, 30.0
    fitness = alpha * fp16_iou + beta * min(fp16_fps / fps_target, 1.0)

    individual.fitness = fitness
    individual.metric  = fp16_iou
    individual.fps     = fp16_fps

    pop.df.loc[idx, "fp32_gpu_iou"] = fp32_iou
    pop.df.loc[idx, "fp32_gpu_fps"] = fp32_fps
    pop.df.loc[idx, "fp16_gpu_iou"] = fp16_iou
    pop.df.loc[idx, "fp16_gpu_fps"] = fp16_fps
    pop.df.loc[idx, "Fitness"]      = fitness
    pop.df.loc[idx, "GPU_IoU"]      = fp16_iou
    pop.df.loc[idx, "GPU_FPS"]      = fp16_fps

    metrics = {
        "gen":      gen,
        "idx":      idx,
        "params":   individual.model_size,
        "fp32_iou": fp32_iou,
        "fp32_fps": fp32_fps,
        "fp16_iou": fp16_iou,
        "fp16_fps": fp16_fps,
        "fitness":  fitness,
        "fp32_model": str(gen_dir / "model_fp32.pt"),
        "fp16_model": str(gen_dir / "model_fp16aware.pt"),
    }
    json.dump(metrics, open(gen_dir / "metrics.json", "w"), indent=2)

    # checkpoint after every candidate so restarts lose at most one model
    pop.save_dataframe()
    pop.save_population()

    print(f"  [{idx:02d}] DONE  — params={individual.model_size:,}  "
          f"fp32={fp32_iou:.4f}  fp16={fp16_iou:.4f}  "
          f"fitness={fitness:.4f}  VRAM_free={free_vram_gb(0):.1f}GB")
    return metrics


print("train_two_scenarios defined ✓")
print(f"  NAS search : {FP32_EPOCHS} FP32 + {FP16_EPOCHS} FP16 epochs, "
      f"batch {BATCH_SIZE}×2 accumulation")
print(f"  Final train: 50 FP32 + 15 FP16 epochs (Cell 11)")
# Out:
# train_two_scenarios defined ✓
#   NAS search : 12 FP32 + 12 FP16 epochs, batch 8×2 accumulation
#   Final train: 50 FP32 + 15 FP16 epochs (Cell 11)

# %% [markdown]
# ## Cell 9 — Create population
#
# `Population` generates `n_individuals` random candidate architectures and
# validates that each fits within the `max_parameters` budget.
# `initial_poll()` triggers this generation and saves a checkpoint.
#
# **Expected output:** a progress bar while 50 architectures are generated.

# %%
pop = Population(
    n_individuals  = N_INDIVIDUALS,
    max_layers     = MAX_LAYERS,
    dm             = dm_nas,
    max_parameters = MAX_PARAMS,
    save_directory = SAVE_DIR,
)
pop.cfg = config   # must be set before initial_poll so QAT opts are readable

# ── Resume from checkpoint if one exists (survives kernel restarts) ──────────
checkpoint_pkl = f"{SAVE_DIR}/src/population_0.pkl"
checkpoint_df  = f"{SAVE_DIR}/src/df_population_0.pkl"
if os.path.exists(checkpoint_pkl):
    import pickle
    pop.population = pickle.load(open(checkpoint_pkl, "rb"))
    pop.df         = pd.read_pickle(checkpoint_df)
    n_done = pop.df["Fitness"].notna().sum() if "Fitness" in pop.df.columns else 0
    print(f"Resumed from checkpoint: {len(pop.population)} individuals, "
          f"{n_done} already trained")
else:
    pop.initial_poll()
    print(f"Fresh population: {len(pop.population)} individuals")

print(pop.df[["Generation", "Params"]].describe())
assert len(pop.population) >= int(N_INDIVIDUALS * 0.8), \
    f"population too small: {len(pop.population)}/{N_INDIVIDUALS}"
print(f"Population ready: {len(pop.population)}/{N_INDIVIDUALS} ✓")
# Out:
# Resumed from checkpoint: 45 individuals, 0 already trained
#        Generation        Params
# count        45.0  4.500000e+01
# mean          0.0  3.300656e+05
# std           0.0  3.923682e+05
# min           0.0  4.606000e+03
# 25%           0.0  5.183500e+04
# 50%           0.0  1.817640e+05
# 75%           0.0  4.695380e+05
# max           0.0  1.562028e+06
# Population ready: 45/50 ✓

# %% [markdown]
# ## Cell 10 — NAS search loop
#
# Runs `MAX_ITER=3` generations, each training all 50 candidates through the
# two-scenario pipeline.
#
# **Total:** 3 × 50 = 150 model trainings.
# **Resume-safe:** if the kernel crashes, re-running this cell skips any
# candidate that already has a valid `Fitness` value in `pop.df`.
#
# At the end of each generation except the last, `pop.evolve()` applies
# crossover + mutation to produce the next generation's 50 candidates,
# carrying forward the `k_best=2` elite models unchanged.

# %%
STOP_ON_FIRST_ERROR = True   # set False once root cause is identified

for gen_idx in range(MAX_ITER):
    print(f"\n{'='*65}")
    print(f"  GENERATION {pop.generation + 1} / {MAX_ITER} — {len(pop.population)} candidates")
    print(f"{'='*65}")

    first_error_idx = None

    for idx in range(len(pop.population)):
        # resume-safe: skip if this candidate was already trained this generation
        if (pop.df is not None and
            "Fitness" in pop.df.columns and
            idx < len(pop.df) and
            not pd.isna(pop.df.loc[idx, "Fitness"])):
            print(f"  [{idx:02d}] already trained — skipping")
            continue

        # OOM guard
        free = free_vram_gb(0)
        if free < MIN_FREE_VRAM_GB:
            torch.cuda.empty_cache()
            free = free_vram_gb(0)
        if free < MIN_FREE_VRAM_GB:
            print(f"  [{idx:02d}] only {free:.1f} GB VRAM free — skipping")
            continue

        result = train_two_scenarios(pop, idx, dm=dm_nas)

        if result is None and STOP_ON_FIRST_ERROR:
            first_error_idx = idx
            print(f"\n!! Stopped at idx={idx} with CUDA_LAUNCH_BLOCKING=1")
            print(f"   The traceback above shows the real root cause.")
            print(f"   Fix the issue, set STOP_ON_FIRST_ERROR=False, restart kernel, rerun.")
            break

    # sort and checkpoint regardless of whether we stopped early
    pop._sort_population()
    best = pop.population[0]
    best_fitness = best.fitness if best.fitness is not None else float("nan")
    best_iou     = best.metric  if best.metric  is not None else float("nan")
    best_params  = best.model_size if best.model_size is not None else 0
    print(f"\nGeneration {pop.generation} complete.")
    print(f"  Best: fitness={best_fitness:.4f}  fp16_iou={best_iou:.4f}  "
         f"params={best_params:,}")
    pop._checkpoint()

    if first_error_idx is not None:
        break   # stop outer loop too — don't evolve on a poisoned generation

    # evolve for next generation (skip after the final generation)
    if gen_idx < MAX_ITER - 1:
        pop.evolve(
            mating_pool_cutoff  = POOL_CUTOFF,
            mutation_probability= MUTATION_P,
            k_best              = K_BEST,
            n_random            = N_RANDOM,
        )
        print(f"\nEvolution complete — new generation ready")

# ── Summary ──────────────────────────────────────────────────────────────────
print("\n" + "="*65)
print("NAS SEARCH — DIAGNOSTIC RUN" if STOP_ON_FIRST_ERROR else "NAS SEARCH COMPLETE")
print("="*65)
if pop.df is not None and len(pop.df) > 0:
    avail = [c for c in ["Generation","Params","Fitness","fp32_gpu_iou","fp16_gpu_iou"]
             if c in pop.df.columns]
    print(pop.df[avail].sort_values("Fitness", ascending=False).head(10).to_string())
else:
    print("No completed candidates yet.")
# Out:
# =================================================================
#   GENERATION 1 / 3 — 45 candidates
# =================================================================
#   [00] Scenario 1: FP32  (12 epochs, lr=1.00e-03)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
#
#   | Name    | Type               | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | model   | GenericUNetNetwork | 79.9 K | train | 0
# 1 | loss_fn | CrossEntropyLoss   | 0      | train | 0
# 2 | mse     | MeanSquaredError   | 0      | train | 0
# ---------------------------------------------------------------
# 79.9 K    Trainable params
# 0         Non-trainable params
# 79.9 K    Total params
# 0.320     Total estimated model params size (MB)
# 149       Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# NAS subset: 31,937 tiles (31,937 informative + 0 clear)
# Sanity Checking: |                                                                      | 0/? [00:00<?, ?it/s]
# /root/projects/iride_onboard-burnscar-mapper/.venv/lib/python3.12/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /root/projects/iride_onboard-burnscar-mapper/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:429: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# /root/projects/iride_onboard-burnscar-mapper/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:429: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 0: 100%|████████████████████████████████████████████████████████████| 3992/3992 [04:56<00:00, 13.44it/s]
# Validation: |                                                                           | 0/? [00:00<?, ?it/s]
# Validation: |                                                                           | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                        | 0/796 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                                                | 1/796 [00:00<00:42, 18.56it/s]
# Validation DataLoader 0:   0%|                                                | 2/796 [00:00<00:40, 19.65it/s]
# Validation DataLoader 0:   0%|▏                                               | 3/796 [00:00<01:05, 12.15it/s]
# Validation DataLoader 0:   1%|▏                                               | 4/796 [00:02<06:36,  2.00it/s]
# Validation DataLoader 0:   1%|▎                                               | 5/796 [00:02<05:23,  2.44it/s]
# Validation DataLoader 0:   1%|▎                                               | 6/796 [00:02<04:36,  2.86it/s]
# Validation DataLoader 0:   1%|▍                                               | 7/796 [00:02<04:01,  3.27it/s]
# Validation DataLoader 0:   1%|▍                                               | 8/796 [00:02<03:35,  3.65it/s]
# Validation DataLoader 0:   1%|▌                                               | 9/796 [00:02<03:16,  4.01it/s]
# Validation DataLoader 0:   1%|▌                                              | 10/796 [00:02<03:00,  4.36it/s]
# Validation DataLoader 0:   1%|▋                                              | 11/796 [00:02<02:46,  4.70it/s]
# Validation DataLoader 0:   2%|▋                                              | 12/796 [00:02<02:36,  5.02it/s]
# Validation DataLoader 0:   2%|▊                                              | 13/796 [00:02<02:26,  5.33it/s]
# Validation DataLoader 0:   2%|▊                                              | 14/796 [00:02<02:18,  5.63it/s]
# Validation DataLoader 0:   2%|▉                                              | 15/796 [00:02<02:11,  5.92it/s]
# Validation DataLoader 0:   2%|▉                                              | 16/796 [00:02<02:06,  6.19it/s]
# Validation DataLoader 0:   2%|█                                              | 17/796 [00:02<02:00,  6.46it/s]
# Validation DataLoader 0:   2%|█                                              | 18/796 [00:02<01:55,  6.72it/s]
# Validation DataLoader 0:   2%|█                                              | 19/796 [00:02<01:51,  6.97it/s]
# Validation DataLoader 0:   3%|█▏                                             | 20/796 [00:02<01:47,  7.22it/s]
# Validation DataLoader 0:   3%|█▏                                             | 21/796 [00:02<01:44,  7.45it/s]
# Validation DataLoader 0:   3%|█▎                                             | 22/796 [00:02<01:40,  7.67it/s]
# Validation DataLoader 0:   3%|█▎                                             | 23/796 [00:02<01:38,  7.88it/s]
# Validation DataLoader 0:   3%|█▍                                             | 24/796 [00:02<01:35,  8.09it/s]
# Validation DataLoader 0:   3%|█▍                                             | 25/796 [00:03<01:32,  8.29it/s]
# Validation DataLoader 0:   3%|█▌                                             | 26/796 [00:03<01:30,  8.49it/s]
# Validation DataLoader 0:   3%|█▌                                             | 27/796 [00:03<01:28,  8.68it/s]
# Validation DataLoader 0:   4%|█▋                                             | 28/796 [00:03<01:26,  8.87it/s]
# Validation DataLoader 0:   4%|█▋                                             | 29/796 [00:03<01:24,  9.05it/s]
# Validation DataLoader 0:   4%|█▊                                             | 30/796 [00:03<01:23,  9.22it/s]
# Validation DataLoader 0:   4%|█▊                                             | 31/796 [00:03<01:21,  9.39it/s]
# Validation DataLoader 0:   4%|█▉                                             | 32/796 [00:03<01:19,  9.55it/s]
# Validation DataLoader 0:   4%|█▉                                             | 33/796 [00:03<01:18,  9.71it/s]
# Validation DataLoader 0:   4%|██                                             | 34/796 [00:03<01:17,  9.87it/s]
# Validation DataLoader 0:   4%|██                                             | 35/796 [00:03<01:15, 10.02it/s]
# Validation DataLoader 0:   5%|██▏                                            | 36/796 [00:03<01:14, 10.16it/s]
# Validation DataLoader 0:   5%|██▏                                            | 37/796 [00:03<01:13, 10.30it/s]
# Validation DataLoader 0:   5%|██▏                                            | 38/796 [00:03<01:12, 10.43it/s]
# Validation DataLoader 0:   5%|██▎                                            | 39/796 [00:03<01:11, 10.56it/s]
# Validation DataLoader 0:   5%|██▎                                            | 40/796 [00:03<01:10, 10.70it/s]
# Validation DataLoader 0:   5%|██▍                                            | 41/796 [00:03<01:09, 10.83it/s]
# Validation DataLoader 0:   5%|██▍                                            | 42/796 [00:03<01:08, 10.96it/s]
# Validation DataLoader 0:   5%|██▌                                            | 43/796 [00:03<01:07, 11.08it/s]
# Validation DataLoader 0:   6%|██▌                                            | 44/796 [00:03<01:07, 11.20it/s]
# Validation DataLoader 0:   6%|██▋                                            | 45/796 [00:03<01:06, 11.31it/s]
# Validation DataLoader 0:   6%|██▋                                            | 46/796 [00:04<01:05, 11.42it/s]
# Validation DataLoader 0:   6%|██▊                                            | 47/796 [00:04<01:04, 11.53it/s]
# Validation DataLoader 0:   6%|██▊                                            | 48/796 [00:04<01:04, 11.64it/s]
# Validation DataLoader 0:   6%|██▉                                            | 49/796 [00:04<01:03, 11.75it/s]
# Validation DataLoader 0:   6%|██▉                                            | 50/796 [00:04<01:02, 11.85it/s]
# Validation DataLoader 0:   6%|███                                            | 51/796 [00:04<01:02, 11.95it/s]
# Validation DataLoader 0:   7%|███                                            | 52/796 [00:04<01:01, 12.05it/s]
# Validation DataLoader 0:   7%|███▏                                           | 53/796 [00:04<01:01, 12.14it/s]
# Validation DataLoader 0:   7%|███▏                                           | 54/796 [00:04<01:00, 12.24it/s]
# Validation DataLoader 0:   7%|███▏                                           | 55/796 [00:04<01:00, 12.32it/s]
# Validation DataLoader 0:   7%|███▎                                           | 56/796 [00:04<00:59, 12.41it/s]
# Validation DataLoader 0:   7%|███▎                                           | 57/796 [00:04<00:59, 12.49it/s]
# Validation DataLoader 0:   7%|███▍                                           | 58/796 [00:04<00:58, 12.58it/s]
# Validation DataLoader 0:   7%|███▍                                           | 59/796 [00:04<00:58, 12.66it/s]
# Validation DataLoader 0:   8%|███▌                                           | 60/796 [00:04<00:57, 12.73it/s]
# Validation DataLoader 0:   8%|███▌                                           | 61/796 [00:04<00:57, 12.82it/s]
# Validation DataLoader 0:   8%|███▋                                           | 62/796 [00:04<00:56, 12.90it/s]
# Validation DataLoader 0:   8%|███▋                                           | 63/796 [00:04<00:56, 12.98it/s]
# Validation DataLoader 0:   8%|███▊                                           | 64/796 [00:04<00:56, 13.06it/s]
# Validation DataLoader 0:   8%|███▊                                           | 65/796 [00:04<00:55, 13.12it/s]
# Validation DataLoader 0:   8%|███▉                                           | 66/796 [00:05<00:55, 13.20it/s]
# Validation DataLoader 0:   8%|███▉                                           | 67/796 [00:05<00:54, 13.27it/s]
# Validation DataLoader 0:   9%|████                                           | 68/796 [00:05<00:54, 13.34it/s]
# Validation DataLoader 0:   9%|████                                           | 69/796 [00:05<00:54, 13.41it/s]
# Validation DataLoader 0:   9%|████▏                                          | 70/796 [00:05<00:53, 13.48it/s]
# Validation DataLoader 0:   9%|████▏                                          | 71/796 [00:05<00:53, 13.54it/s]
# Validation DataLoader 0:   9%|████▎                                          | 72/796 [00:05<00:53, 13.61it/s]
# Validation DataLoader 0:   9%|████▎                                          | 73/796 [00:05<00:52, 13.67it/s]
# Validation DataLoader 0:   9%|████▎                                          | 74/796 [00:05<00:52, 13.74it/s]
# Validation DataLoader 0:   9%|████▍                                          | 75/796 [00:05<00:52, 13.80it/s]
# Validation DataLoader 0:  10%|████▍                                          | 76/796 [00:05<00:51, 13.86it/s]
# Validation DataLoader 0:  10%|████▌                                          | 77/796 [00:05<00:51, 13.92it/s]
# Validation DataLoader 0:  10%|████▌                                          | 78/796 [00:05<00:51, 13.99it/s]
# Validation DataLoader 0:  10%|████▋                                          | 79/796 [00:05<00:51, 14.05it/s]
# Validation DataLoader 0:  10%|████▋                                          | 80/796 [00:05<00:50, 14.11it/s]
# Validation DataLoader 0:  10%|████▊                                          | 81/796 [00:05<00:50, 14.17it/s]
# Validation DataLoader 0:  10%|████▊                                          | 82/796 [00:05<00:50, 14.23it/s]
# Validation DataLoader 0:  10%|████▉                                          | 83/796 [00:05<00:49, 14.28it/s]
# Validation DataLoader 0:  11%|████▉                                          | 84/796 [00:05<00:49, 14.33it/s]
# Validation DataLoader 0:  11%|█████                                          | 85/796 [00:05<00:49, 14.39it/s]
# Validation DataLoader 0:  11%|█████                                          | 86/796 [00:05<00:49, 14.44it/s]
# Validation DataLoader 0:  11%|█████▏                                         | 87/796 [00:06<00:48, 14.49it/s]
# Validation DataLoader 0:  11%|█████▏                                         | 88/796 [00:06<00:48, 14.54it/s]
# Validation DataLoader 0:  11%|█████▎                                         | 89/796 [00:06<00:48, 14.60it/s]
# Validation DataLoader 0:  11%|█████▎                                         | 90/796 [00:06<00:48, 14.64it/s]
# Validation DataLoader 0:  11%|█████▎                                         | 91/796 [00:06<00:47, 14.69it/s]
# Validation DataLoader 0:  12%|█████▍                                         | 92/796 [00:06<00:47, 14.74it/s]
# Validation DataLoader 0:  12%|█████▍                                         | 93/796 [00:06<00:47, 14.79it/s]
# Validation DataLoader 0:  12%|█████▌                                         | 94/796 [00:06<00:47, 14.83it/s]
# Validation DataLoader 0:  12%|█████▌                                         | 95/796 [00:06<00:47, 14.88it/s]
# Validation DataLoader 0:  12%|█████▋                                         | 96/796 [00:06<00:46, 14.93it/s]
# Validation DataLoader 0:  12%|█████▋                                         | 97/796 [00:06<00:46, 14.98it/s]
# Validation DataLoader 0:  12%|█████▊                                         | 98/796 [00:06<00:46, 15.02it/s]
# Validation DataLoader 0:  12%|█████▊                                         | 99/796 [00:06<00:46, 15.07it/s]
# Validation DataLoader 0:  13%|█████▊                                        | 100/796 [00:06<00:46, 15.11it/s]
# Validation DataLoader 0:  13%|█████▊                                        | 101/796 [00:06<00:45, 15.16it/s]
# Validation DataLoader 0:  13%|█████▉                                        | 102/796 [00:06<00:45, 15.20it/s]
# Validation DataLoader 0:  13%|█████▉                                        | 103/796 [00:06<00:45, 15.24it/s]
# Validation DataLoader 0:  13%|██████                                        | 104/796 [00:06<00:45, 15.29it/s]
# Validation DataLoader 0:  13%|██████                                        | 105/796 [00:06<00:45, 15.33it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 106/796 [00:06<00:44, 15.37it/s]
# Validation DataLoader 0:  13%|██████▏                                       | 107/796 [00:06<00:44, 15.41it/s]
# Validation DataLoader 0:  14%|██████▏                                       | 108/796 [00:06<00:44, 15.45it/s]
# Validation DataLoader 0:  14%|██████▎                                       | 109/796 [00:07<00:44, 15.49it/s]
# Validation DataLoader 0:  14%|██████▎                                       | 110/796 [00:07<00:44, 15.53it/s]
# Validation DataLoader 0:  14%|██████▍                                       | 111/796 [00:07<00:43, 15.57it/s]
# Validation DataLoader 0:  14%|██████▍                                       | 112/796 [00:07<00:43, 15.61it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 113/796 [00:07<00:43, 15.64it/s]
# Validation DataLoader 0:  14%|██████▌                                       | 114/796 [00:07<00:43, 15.68it/s]
# Validation DataLoader 0:  14%|██████▋                                       | 115/796 [00:07<00:43, 15.72it/s]
# Validation DataLoader 0:  15%|██████▋                                       | 116/796 [00:07<00:43, 15.75it/s]
# Validation DataLoader 0:  15%|██████▊                                       | 117/796 [00:07<00:43, 15.78it/s]
# Validation DataLoader 0:  15%|██████▊                                       | 118/796 [00:07<00:42, 15.81it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 119/796 [00:07<00:42, 15.84it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 120/796 [00:07<00:42, 15.87it/s]
# Validation DataLoader 0:  15%|██████▉                                       | 121/796 [00:07<00:42, 15.91it/s]
# Validation DataLoader 0:  15%|███████                                       | 122/796 [00:07<00:42, 15.93it/s]
# Validation DataLoader 0:  15%|███████                                       | 123/796 [00:07<00:42, 15.96it/s]
# Validation DataLoader 0:  16%|███████▏                                      | 124/796 [00:07<00:42, 15.99it/s]
# Validation DataLoader 0:  16%|███████▏                                      | 125/796 [00:07<00:41, 16.02it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 126/796 [00:07<00:41, 16.05it/s]
# Validation DataLoader 0:  16%|███████▎                                      | 127/796 [00:07<00:41, 16.08it/s]
# Validation DataLoader 0:  16%|███████▍                                      | 128/796 [00:07<00:41, 16.11it/s]
# Validation DataLoader 0:  16%|███████▍                                      | 129/796 [00:07<00:41, 16.14it/s]
# Validation DataLoader 0:  16%|███████▌                                      | 130/796 [00:08<00:41, 16.17it/s]
# Validation DataLoader 0:  16%|███████▌                                      | 131/796 [00:08<00:41, 16.20it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 132/796 [00:08<00:40, 16.23it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 133/796 [00:08<00:40, 16.25it/s]
# Validation DataLoader 0:  17%|███████▋                                      | 134/796 [00:08<00:40, 16.28it/s]
# Validation DataLoader 0:  17%|███████▊                                      | 135/796 [00:08<00:40, 16.31it/s]
# Validation DataLoader 0:  17%|███████▊                                      | 136/796 [00:08<00:40, 16.33it/s]
# Validation DataLoader 0:  17%|███████▉                                      | 137/796 [00:08<00:40, 16.36it/s]
# Validation DataLoader 0:  17%|███████▉                                      | 138/796 [00:08<00:40, 16.39it/s]
# Validation DataLoader 0:  17%|████████                                      | 139/796 [00:08<00:40, 16.41it/s]
# Validation DataLoader 0:  18%|████████                                      | 140/796 [00:08<00:39, 16.44it/s]
# Validation DataLoader 0:  18%|████████▏                                     | 141/796 [00:08<00:39, 16.46it/s]
# Validation DataLoader 0:  18%|████████▏                                     | 142/796 [00:08<00:39, 16.48it/s]
# Validation DataLoader 0:  18%|████████▎                                     | 143/796 [00:08<00:39, 16.51it/s]
# Validation DataLoader 0:  18%|████████▎                                     | 144/796 [00:08<00:39, 16.53it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 145/796 [00:08<00:39, 16.56it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 146/796 [00:08<00:39, 16.58it/s]
# Validation DataLoader 0:  18%|████████▍                                     | 147/796 [00:08<00:39, 16.61it/s]
# Validation DataLoader 0:  19%|████████▌                                     | 148/796 [00:08<00:38, 16.63it/s]
# Validation DataLoader 0:  19%|████████▌                                     | 149/796 [00:08<00:38, 16.66it/s]
# Validation DataLoader 0:  19%|████████▋                                     | 150/796 [00:08<00:38, 16.68it/s]
# Validation DataLoader 0:  19%|████████▋                                     | 151/796 [00:09<00:38, 16.70it/s]
# Validation DataLoader 0:  19%|████████▊                                     | 152/796 [00:09<00:38, 16.72it/s]
# Validation DataLoader 0:  19%|████████▊                                     | 153/796 [00:09<00:38, 16.74it/s]
# Validation DataLoader 0:  19%|████████▉                                     | 154/796 [00:09<00:38, 16.77it/s]
# Validation DataLoader 0:  19%|████████▉                                     | 155/796 [00:09<00:38, 16.79it/s]
# Validation DataLoader 0:  20%|█████████                                     | 156/796 [00:09<00:38, 16.81it/s]
# Validation DataLoader 0:  20%|█████████                                     | 157/796 [00:09<00:37, 16.84it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 158/796 [00:09<00:37, 16.86it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 159/796 [00:09<00:37, 16.88it/s]
# Validation DataLoader 0:  20%|█████████▏                                    | 160/796 [00:09<00:37, 16.90it/s]
# Validation DataLoader 0:  20%|█████████▎                                    | 161/796 [00:09<00:37, 16.93it/s]
# Validation DataLoader 0:  20%|█████████▎                                    | 162/796 [00:09<00:37, 16.95it/s]
# Validation DataLoader 0:  20%|█████████▍                                    | 163/796 [00:09<00:37, 16.96it/s]
# Validation DataLoader 0:  21%|█████████▍                                    | 164/796 [00:09<00:37, 16.98it/s]
# Validation DataLoader 0:  21%|█████████▌                                    | 165/796 [00:09<00:37, 17.00it/s]
# Validation DataLoader 0:  21%|█████████▌                                    | 166/796 [00:09<00:37, 17.02it/s]
# Validation DataLoader 0:  21%|█████████▋                                    | 167/796 [00:09<00:36, 17.04it/s]
# Validation DataLoader 0:  21%|█████████▋                                    | 168/796 [00:09<00:36, 17.06it/s]
# Validation DataLoader 0:  21%|█████████▊                                    | 169/796 [00:09<00:36, 17.08it/s]
# Validation DataLoader 0:  21%|█████████▊                                    | 170/796 [00:09<00:36, 17.10it/s]
# Validation DataLoader 0:  21%|█████████▉                                    | 171/796 [00:09<00:36, 17.12it/s]
# Validation DataLoader 0:  22%|█████████▉                                    | 172/796 [00:10<00:36, 17.14it/s]
# Validation DataLoader 0:  22%|█████████▉                                    | 173/796 [00:10<00:36, 17.16it/s]
# Validation DataLoader 0:  22%|██████████                                    | 174/796 [00:10<00:36, 17.17it/s]
# Validation DataLoader 0:  22%|██████████                                    | 175/796 [00:10<00:36, 17.19it/s]
# Validation DataLoader 0:  22%|██████████▏                                   | 176/796 [00:10<00:36, 17.21it/s]
# Validation DataLoader 0:  22%|██████████▏                                   | 177/796 [00:10<00:35, 17.22it/s]
# Validation DataLoader 0:  22%|██████████▎                                   | 178/796 [00:10<00:35, 17.24it/s]
# Validation DataLoader 0:  22%|██████████▎                                   | 179/796 [00:10<00:35, 17.26it/s]
# Validation DataLoader 0:  23%|██████████▍                                   | 180/796 [00:10<00:35, 17.27it/s]
# Validation DataLoader 0:  23%|██████████▍                                   | 181/796 [00:10<00:35, 17.29it/s]
# Validation DataLoader 0:  23%|██████████▌                                   | 182/796 [00:10<00:35, 17.31it/s]
# Validation DataLoader 0:  23%|██████████▌                                   | 183/796 [00:10<00:35, 17.33it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 184/796 [00:10<00:35, 17.34it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 185/796 [00:10<00:35, 17.36it/s]
# Validation DataLoader 0:  23%|██████████▋                                   | 186/796 [00:10<00:35, 17.37it/s]
# Validation DataLoader 0:  23%|██████████▊                                   | 187/796 [00:10<00:35, 17.38it/s]
# Validation DataLoader 0:  24%|██████████▊                                   | 188/796 [00:10<00:34, 17.40it/s]
# Validation DataLoader 0:  24%|██████████▉                                   | 189/796 [00:10<00:34, 17.42it/s]
# Validation DataLoader 0:  24%|██████████▉                                   | 190/796 [00:10<00:34, 17.44it/s]
# Validation DataLoader 0:  24%|███████████                                   | 191/796 [00:10<00:34, 17.45it/s]
# Validation DataLoader 0:  24%|███████████                                   | 192/796 [00:10<00:34, 17.47it/s]
# Validation DataLoader 0:  24%|███████████▏                                  | 193/796 [00:11<00:34, 17.49it/s]
# Validation DataLoader 0:  24%|███████████▏                                  | 194/796 [00:11<00:34, 17.50it/s]
# Validation DataLoader 0:  24%|███████████▎                                  | 195/796 [00:11<00:34, 17.52it/s]
# Validation DataLoader 0:  25%|███████████▎                                  | 196/796 [00:11<00:34, 17.54it/s]
# Validation DataLoader 0:  25%|███████████▍                                  | 197/796 [00:11<00:34, 17.55it/s]
# Validation DataLoader 0:  25%|███████████▍                                  | 198/796 [00:11<00:34, 17.56it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 199/796 [00:11<00:33, 17.57it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 200/796 [00:11<00:33, 17.59it/s]
# Validation DataLoader 0:  25%|███████████▌                                  | 201/796 [00:11<00:33, 17.60it/s]
# Validation DataLoader 0:  25%|███████████▋                                  | 202/796 [00:11<00:33, 17.62it/s]
# Validation DataLoader 0:  26%|███████████▋                                  | 203/796 [00:11<00:33, 17.63it/s]
# Validation DataLoader 0:  26%|███████████▊                                  | 204/796 [00:11<00:33, 17.65it/s]
# Validation DataLoader 0:  26%|███████████▊                                  | 205/796 [00:11<00:33, 17.67it/s]
# Validation DataLoader 0:  26%|███████████▉                                  | 206/796 [00:11<00:33, 17.68it/s]
# Validation DataLoader 0:  26%|███████████▉                                  | 207/796 [00:11<00:33, 17.70it/s]
# Validation DataLoader 0:  26%|████████████                                  | 208/796 [00:11<00:33, 17.71it/s]
# Validation DataLoader 0:  26%|████████████                                  | 209/796 [00:11<00:33, 17.73it/s]
# Validation DataLoader 0:  26%|████████████▏                                 | 210/796 [00:11<00:33, 17.73it/s]
# Validation DataLoader 0:  27%|████████████▏                                 | 211/796 [00:11<00:32, 17.75it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 212/796 [00:11<00:32, 17.76it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 213/796 [00:11<00:32, 17.77it/s]
# Validation DataLoader 0:  27%|████████████▎                                 | 214/796 [00:12<00:32, 17.78it/s]
# Validation DataLoader 0:  27%|████████████▍                                 | 215/796 [00:12<00:32, 17.80it/s]
# Validation DataLoader 0:  27%|████████████▍                                 | 216/796 [00:12<00:32, 17.81it/s]
# Validation DataLoader 0:  27%|████████████▌                                 | 217/796 [00:12<00:32, 17.82it/s]
# Validation DataLoader 0:  27%|████████████▌                                 | 218/796 [00:12<00:32, 17.83it/s]
# Validation DataLoader 0:  28%|████████████▋                                 | 219/796 [00:12<00:32, 17.85it/s]
# Validation DataLoader 0:  28%|████████████▋                                 | 220/796 [00:12<00:32, 17.86it/s]
# Validation DataLoader 0:  28%|████████████▊                                 | 221/796 [00:12<00:32, 17.87it/s]
# Validation DataLoader 0:  28%|████████████▊                                 | 222/796 [00:12<00:32, 17.88it/s]
# Validation DataLoader 0:  28%|████████████▉                                 | 223/796 [00:12<00:32, 17.90it/s]
# Validation DataLoader 0:  28%|████████████▉                                 | 224/796 [00:12<00:31, 17.91it/s]
# Validation DataLoader 0:  28%|█████████████                                 | 225/796 [00:12<00:31, 17.92it/s]
# Validation DataLoader 0:  28%|█████████████                                 | 226/796 [00:12<00:31, 17.93it/s]
# Validation DataLoader 0:  29%|█████████████                                 | 227/796 [00:12<00:31, 17.94it/s]
# Validation DataLoader 0:  29%|█████████████▏                                | 228/796 [00:12<00:31, 17.96it/s]
# Validation DataLoader 0:  29%|█████████████▏                                | 229/796 [00:12<00:31, 17.97it/s]
# Validation DataLoader 0:  29%|█████████████▎                                | 230/796 [00:12<00:31, 17.98it/s]
# Validation DataLoader 0:  29%|█████████████▎                                | 231/796 [00:12<00:31, 17.99it/s]
# Validation DataLoader 0:  29%|█████████████▍                                | 232/796 [00:12<00:31, 18.00it/s]
# Validation DataLoader 0:  29%|█████████████▍                                | 233/796 [00:12<00:31, 18.01it/s]
# Validation DataLoader 0:  29%|█████████████▌                                | 234/796 [00:12<00:31, 18.02it/s]
# Validation DataLoader 0:  30%|█████████████▌                                | 235/796 [00:13<00:31, 18.03it/s]
# Validation DataLoader 0:  30%|█████████████▋                                | 236/796 [00:13<00:31, 18.04it/s]
# Validation DataLoader 0:  30%|█████████████▋                                | 237/796 [00:13<00:30, 18.05it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 238/796 [00:13<00:30, 18.06it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 239/796 [00:13<00:30, 18.07it/s]
# Validation DataLoader 0:  30%|█████████████▊                                | 240/796 [00:13<00:30, 18.08it/s]
# Validation DataLoader 0:  30%|█████████████▉                                | 241/796 [00:13<00:30, 18.09it/s]
# Validation DataLoader 0:  30%|█████████████▉                                | 242/796 [00:13<00:30, 18.10it/s]
# Validation DataLoader 0:  31%|██████████████                                | 243/796 [00:13<00:30, 18.11it/s]
# Validation DataLoader 0:  31%|██████████████                                | 244/796 [00:13<00:30, 18.12it/s]
# Validation DataLoader 0:  31%|██████████████▏                               | 245/796 [00:13<00:30, 18.14it/s]
# Validation DataLoader 0:  31%|██████████████▏                               | 246/796 [00:13<00:30, 18.15it/s]
# Validation DataLoader 0:  31%|██████████████▎                               | 247/796 [00:13<00:30, 18.16it/s]
# Validation DataLoader 0:  31%|██████████████▎                               | 248/796 [00:13<00:30, 18.17it/s]
# Validation DataLoader 0:  31%|██████████████▍                               | 249/796 [00:13<00:30, 18.18it/s]
# Validation DataLoader 0:  31%|██████████████▍                               | 250/796 [00:13<00:30, 18.19it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 251/796 [00:13<00:29, 18.20it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 252/796 [00:13<00:29, 18.21it/s]
# Validation DataLoader 0:  32%|██████████████▌                               | 253/796 [00:13<00:29, 18.22it/s]
# Validation DataLoader 0:  32%|██████████████▋                               | 254/796 [00:13<00:29, 18.23it/s]
# Validation DataLoader 0:  32%|██████████████▋                               | 255/796 [00:13<00:29, 18.24it/s]
# Validation DataLoader 0:  32%|██████████████▊                               | 256/796 [00:14<00:29, 18.25it/s]
# Validation DataLoader 0:  32%|██████████████▊                               | 257/796 [00:14<00:29, 18.27it/s]
# Validation DataLoader 0:  32%|██████████████▉                               | 258/796 [00:14<00:29, 18.28it/s]
# Validation DataLoader 0:  33%|██████████████▉                               | 259/796 [00:14<00:29, 18.29it/s]
# Validation DataLoader 0:  33%|███████████████                               | 260/796 [00:14<00:29, 18.30it/s]
# Validation DataLoader 0:  33%|███████████████                               | 261/796 [00:14<00:29, 18.31it/s]
# Validation DataLoader 0:  33%|███████████████▏                              | 262/796 [00:14<00:29, 18.32it/s]
# Validation DataLoader 0:  33%|███████████████▏                              | 263/796 [00:14<00:29, 18.33it/s]
# Validation DataLoader 0:  33%|███████████████▎                              | 264/796 [00:14<00:28, 18.34it/s]
# Validation DataLoader 0:  33%|███████████████▎                              | 265/796 [00:14<00:28, 18.35it/s]
# Validation DataLoader 0:  33%|███████████████▎                              | 266/796 [00:14<00:28, 18.36it/s]
# Validation DataLoader 0:  34%|███████████████▍                              | 267/796 [00:14<00:28, 18.37it/s]
# Validation DataLoader 0:  34%|███████████████▍                              | 268/796 [00:14<00:28, 18.38it/s]
# Validation DataLoader 0:  34%|███████████████▌                              | 269/796 [00:14<00:28, 18.39it/s]
# Validation DataLoader 0:  34%|███████████████▌                              | 270/796 [00:14<00:28, 18.40it/s]
# Validation DataLoader 0:  34%|███████████████▋                              | 271/796 [00:14<00:28, 18.41it/s]
# Validation DataLoader 0:  34%|███████████████▋                              | 272/796 [00:14<00:28, 18.42it/s]
# Validation DataLoader 0:  34%|███████████████▊                              | 273/796 [00:14<00:28, 18.43it/s]
# Validation DataLoader 0:  34%|███████████████▊                              | 274/796 [00:14<00:28, 18.44it/s]
# Validation DataLoader 0:  35%|███████████████▉                              | 275/796 [00:14<00:28, 18.45it/s]
# Validation DataLoader 0:  35%|███████████████▉                              | 276/796 [00:14<00:28, 18.46it/s]
# Validation DataLoader 0:  35%|████████████████                              | 277/796 [00:15<00:28, 18.46it/s]
# Validation DataLoader 0:  35%|████████████████                              | 278/796 [00:15<00:28, 18.47it/s]
# Validation DataLoader 0:  35%|████████████████                              | 279/796 [00:15<00:27, 18.48it/s]
# Validation DataLoader 0:  35%|████████████████▏                             | 280/796 [00:15<00:27, 18.49it/s]
# Validation DataLoader 0:  35%|████████████████▏                             | 281/796 [00:15<00:27, 18.50it/s]
# Validation DataLoader 0:  35%|████████████████▎                             | 282/796 [00:15<00:27, 18.51it/s]
# Validation DataLoader 0:  36%|████████████████▎                             | 283/796 [00:15<00:27, 18.52it/s]
# Validation DataLoader 0:  36%|████████████████▍                             | 284/796 [00:15<00:27, 18.53it/s]
# Validation DataLoader 0:  36%|████████████████▍                             | 285/796 [00:15<00:27, 18.54it/s]
# Validation DataLoader 0:  36%|████████████████▌                             | 286/796 [00:15<00:27, 18.54it/s]
# Validation DataLoader 0:  36%|████████████████▌                             | 287/796 [00:15<00:27, 18.55it/s]
# Validation DataLoader 0:  36%|████████████████▋                             | 288/796 [00:15<00:27, 18.55it/s]
# Validation DataLoader 0:  36%|████████████████▋                             | 289/796 [00:15<00:27, 18.56it/s]
# Validation DataLoader 0:  36%|████████████████▊                             | 290/796 [00:15<00:27, 18.57it/s]
# Validation DataLoader 0:  37%|████████████████▊                             | 291/796 [00:15<00:27, 18.58it/s]
# Validation DataLoader 0:  37%|████████████████▊                             | 292/796 [00:15<00:27, 18.59it/s]
# Validation DataLoader 0:  37%|████████████████▉                             | 293/796 [00:15<00:27, 18.59it/s]
# Validation DataLoader 0:  37%|████████████████▉                             | 294/796 [00:15<00:26, 18.60it/s]
# Validation DataLoader 0:  37%|█████████████████                             | 295/796 [00:15<00:26, 18.60it/s]
# Validation DataLoader 0:  37%|█████████████████                             | 296/796 [00:15<00:26, 18.61it/s]
# Validation DataLoader 0:  37%|█████████████████▏                            | 297/796 [00:15<00:26, 18.62it/s]
# Validation DataLoader 0:  37%|█████████████████▏                            | 298/796 [00:15<00:26, 18.63it/s]
# Validation DataLoader 0:  38%|█████████████████▎                            | 299/796 [00:16<00:26, 18.64it/s]
# Validation DataLoader 0:  38%|█████████████████▎                            | 300/796 [00:16<00:26, 18.64it/s]
# Validation DataLoader 0:  38%|█████████████████▍                            | 301/796 [00:16<00:26, 18.65it/s]
# Validation DataLoader 0:  38%|█████████████████▍                            | 302/796 [00:16<00:26, 18.66it/s]
# Validation DataLoader 0:  38%|█████████████████▌                            | 303/796 [00:16<00:26, 18.67it/s]
# Validation DataLoader 0:  38%|█████████████████▌                            | 304/796 [00:16<00:26, 18.68it/s]
# Validation DataLoader 0:  38%|█████████████████▋                            | 305/796 [00:16<00:26, 18.68it/s]
# Validation DataLoader 0:  38%|█████████████████▋                            | 306/796 [00:16<00:26, 18.69it/s]
# Validation DataLoader 0:  39%|█████████████████▋                            | 307/796 [00:16<00:26, 18.70it/s]
# Validation DataLoader 0:  39%|█████████████████▊                            | 308/796 [00:16<00:26, 18.70it/s]
# Validation DataLoader 0:  39%|█████████████████▊                            | 309/796 [00:16<00:26, 18.71it/s]
# Validation DataLoader 0:  39%|█████████████████▉                            | 310/796 [00:16<00:25, 18.72it/s]
# Validation DataLoader 0:  39%|█████████████████▉                            | 311/796 [00:16<00:25, 18.73it/s]
# Validation DataLoader 0:  39%|██████████████████                            | 312/796 [00:16<00:25, 18.73it/s]
# Validation DataLoader 0:  39%|██████████████████                            | 313/796 [00:16<00:25, 18.74it/s]
# Validation DataLoader 0:  39%|██████████████████▏                           | 314/796 [00:16<00:25, 18.74it/s]
# Validation DataLoader 0:  40%|██████████████████▏                           | 315/796 [00:16<00:25, 18.75it/s]
# Validation DataLoader 0:  40%|██████████████████▎                           | 316/796 [00:16<00:25, 18.75it/s]
# Validation DataLoader 0:  40%|██████████████████▎                           | 317/796 [00:16<00:25, 18.76it/s]
# Validation DataLoader 0:  40%|██████████████████▍                           | 318/796 [00:16<00:25, 18.76it/s]
# Validation DataLoader 0:  40%|██████████████████▍                           | 319/796 [00:16<00:25, 18.77it/s]
# Validation DataLoader 0:  40%|██████████████████▍                           | 320/796 [00:17<00:25, 18.78it/s]
# Validation DataLoader 0:  40%|██████████████████▌                           | 321/796 [00:17<00:25, 18.78it/s]
# Validation DataLoader 0:  40%|██████████████████▌                           | 322/796 [00:17<00:25, 18.79it/s]
# Validation DataLoader 0:  41%|██████████████████▋                           | 323/796 [00:17<00:25, 18.79it/s]
# Validation DataLoader 0:  41%|██████████████████▋                           | 324/796 [00:17<00:25, 18.80it/s]
# Validation DataLoader 0:  41%|██████████████████▊                           | 325/796 [00:17<00:25, 18.81it/s]
# Validation DataLoader 0:  41%|██████████████████▊                           | 326/796 [00:17<00:24, 18.82it/s]
# Validation DataLoader 0:  41%|██████████████████▉                           | 327/796 [00:17<00:24, 18.82it/s]
# Validation DataLoader 0:  41%|██████████████████▉                           | 328/796 [00:17<00:24, 18.83it/s]
# Validation DataLoader 0:  41%|███████████████████                           | 329/796 [00:17<00:24, 18.83it/s]
# Validation DataLoader 0:  41%|███████████████████                           | 330/796 [00:17<00:24, 18.84it/s]
# Validation DataLoader 0:  42%|███████████████████▏                          | 331/796 [00:17<00:24, 18.84it/s]
# Validation DataLoader 0:  42%|███████████████████▏                          | 332/796 [00:17<00:24, 18.85it/s]
# Validation DataLoader 0:  42%|███████████████████▏                          | 333/796 [00:17<00:24, 18.86it/s]
# Validation DataLoader 0:  42%|███████████████████▎                          | 334/796 [00:17<00:24, 18.86it/s]
# Validation DataLoader 0:  42%|███████████████████▎                          | 335/796 [00:17<00:24, 18.87it/s]
# Validation DataLoader 0:  42%|███████████████████▍                          | 336/796 [00:17<00:24, 18.88it/s]
# Validation DataLoader 0:  42%|███████████████████▍                          | 337/796 [00:17<00:24, 18.88it/s]
# Validation DataLoader 0:  42%|███████████████████▌                          | 338/796 [00:17<00:24, 18.89it/s]
# Validation DataLoader 0:  43%|███████████████████▌                          | 339/796 [00:17<00:24, 18.89it/s]
# Validation DataLoader 0:  43%|███████████████████▋                          | 340/796 [00:17<00:24, 18.90it/s]
# Validation DataLoader 0:  43%|███████████████████▋                          | 341/796 [00:18<00:24, 18.91it/s]
# Validation DataLoader 0:  43%|███████████████████▊                          | 342/796 [00:18<00:24, 18.91it/s]
# Validation DataLoader 0:  43%|███████████████████▊                          | 343/796 [00:18<00:23, 18.92it/s]
# Validation DataLoader 0:  43%|███████████████████▉                          | 344/796 [00:18<00:23, 18.93it/s]
# Validation DataLoader 0:  43%|███████████████████▉                          | 345/796 [00:18<00:23, 18.93it/s]
# Validation DataLoader 0:  43%|███████████████████▉                          | 346/796 [00:18<00:23, 18.94it/s]
# Validation DataLoader 0:  44%|████████████████████                          | 347/796 [00:18<00:23, 18.94it/s]
# Validation DataLoader 0:  44%|████████████████████                          | 348/796 [00:18<00:23, 18.94it/s]
# Validation DataLoader 0:  44%|████████████████████▏                         | 349/796 [00:18<00:23, 18.95it/s]
# Validation DataLoader 0:  44%|████████████████████▏                         | 350/796 [00:18<00:23, 18.95it/s]
# Validation DataLoader 0:  44%|████████████████████▎                         | 351/796 [00:18<00:23, 18.96it/s]
# Validation DataLoader 0:  44%|████████████████████▎                         | 352/796 [00:18<00:23, 18.97it/s]
# Validation DataLoader 0:  44%|████████████████████▍                         | 353/796 [00:18<00:23, 18.97it/s]
# Validation DataLoader 0:  44%|████████████████████▍                         | 354/796 [00:18<00:23, 18.98it/s]
# Validation DataLoader 0:  45%|████████████████████▌                         | 355/796 [00:18<00:23, 18.98it/s]
# Validation DataLoader 0:  45%|████████████████████▌                         | 356/796 [00:18<00:23, 18.99it/s]
# Validation DataLoader 0:  45%|████████████████████▋                         | 357/796 [00:18<00:23, 19.00it/s]
# Validation DataLoader 0:  45%|████████████████████▋                         | 358/796 [00:18<00:23, 19.00it/s]
# Validation DataLoader 0:  45%|████████████████████▋                         | 359/796 [00:18<00:22, 19.01it/s]
# Validation DataLoader 0:  45%|████████████████████▊                         | 360/796 [00:18<00:22, 19.02it/s]
# Validation DataLoader 0:  45%|████████████████████▊                         | 361/796 [00:18<00:22, 19.02it/s]
# Validation DataLoader 0:  45%|████████████████████▉                         | 362/796 [00:19<00:22, 19.03it/s]
# Validation DataLoader 0:  46%|████████████████████▉                         | 363/796 [00:19<00:22, 19.03it/s]
# Validation DataLoader 0:  46%|█████████████████████                         | 364/796 [00:19<00:22, 19.04it/s]
# Validation DataLoader 0:  46%|█████████████████████                         | 365/796 [00:19<00:22, 19.05it/s]
# Validation DataLoader 0:  46%|█████████████████████▏                        | 366/796 [00:19<00:22, 19.05it/s]
# Validation DataLoader 0:  46%|█████████████████████▏                        | 367/796 [00:19<00:22, 19.06it/s]
# Validation DataLoader 0:  46%|█████████████████████▎                        | 368/796 [00:19<00:22, 19.07it/s]
# Validation DataLoader 0:  46%|█████████████████████▎                        | 369/796 [00:19<00:22, 19.07it/s]
# Validation DataLoader 0:  46%|█████████████████████▍                        | 370/796 [00:19<00:22, 19.08it/s]
# Validation DataLoader 0:  47%|█████████████████████▍                        | 371/796 [00:19<00:22, 19.08it/s]
# Validation DataLoader 0:  47%|█████████████████████▍                        | 372/796 [00:19<00:22, 19.09it/s]
# Validation DataLoader 0:  47%|█████████████████████▌                        | 373/796 [00:19<00:22, 19.10it/s]
# Validation DataLoader 0:  47%|█████████████████████▌                        | 374/796 [00:19<00:22, 19.10it/s]
# Validation DataLoader 0:  47%|█████████████████████▋                        | 375/796 [00:19<00:22, 19.11it/s]
# Validation DataLoader 0:  47%|█████████████████████▋                        | 376/796 [00:19<00:21, 19.11it/s]
# Validation DataLoader 0:  47%|█████████████████████▊                        | 377/796 [00:19<00:21, 19.12it/s]
# Validation DataLoader 0:  47%|█████████████████████▊                        | 378/796 [00:19<00:21, 19.13it/s]
# Validation DataLoader 0:  48%|█████████████████████▉                        | 379/796 [00:19<00:21, 19.13it/s]
# Validation DataLoader 0:  48%|█████████████████████▉                        | 380/796 [00:19<00:21, 19.14it/s]
# Validation DataLoader 0:  48%|██████████████████████                        | 381/796 [00:19<00:21, 19.14it/s]
# Validation DataLoader 0:  48%|██████████████████████                        | 382/796 [00:19<00:21, 19.15it/s]
# Validation DataLoader 0:  48%|██████████████████████▏                       | 383/796 [00:19<00:21, 19.15it/s]
# Validation DataLoader 0:  48%|██████████████████████▏                       | 384/796 [00:20<00:21, 19.16it/s]
# Validation DataLoader 0:  48%|██████████████████████▏                       | 385/796 [00:20<00:21, 19.16it/s]
# Validation DataLoader 0:  48%|██████████████████████▎                       | 386/796 [00:20<00:21, 19.17it/s]
# Validation DataLoader 0:  49%|██████████████████████▎                       | 387/796 [00:20<00:21, 19.17it/s]
# Validation DataLoader 0:  49%|██████████████████████▍                       | 388/796 [00:20<00:21, 19.18it/s]
# Validation DataLoader 0:  49%|██████████████████████▍                       | 389/796 [00:20<00:21, 19.18it/s]
# Validation DataLoader 0:  49%|██████████████████████▌                       | 390/796 [00:20<00:21, 19.19it/s]
# Validation DataLoader 0:  49%|██████████████████████▌                       | 391/796 [00:20<00:21, 19.19it/s]
# Validation DataLoader 0:  49%|██████████████████████▋                       | 392/796 [00:20<00:21, 19.20it/s]
# Validation DataLoader 0:  49%|██████████████████████▋                       | 393/796 [00:20<00:20, 19.20it/s]
# Validation DataLoader 0:  49%|██████████████████████▊                       | 394/796 [00:20<00:20, 19.20it/s]
# Validation DataLoader 0:  50%|██████████████████████▊                       | 395/796 [00:20<00:20, 19.21it/s]
# Validation DataLoader 0:  50%|██████████████████████▉                       | 396/796 [00:20<00:20, 19.21it/s]
# Validation DataLoader 0:  50%|██████████████████████▉                       | 397/796 [00:20<00:20, 19.21it/s]
# Validation DataLoader 0:  50%|███████████████████████                       | 398/796 [00:20<00:20, 19.22it/s]
# Validation DataLoader 0:  50%|███████████████████████                       | 399/796 [00:20<00:20, 19.23it/s]
# Validation DataLoader 0:  50%|███████████████████████                       | 400/796 [00:20<00:20, 19.23it/s]
# Validation DataLoader 0:  50%|███████████████████████▏                      | 401/796 [00:20<00:20, 19.23it/s]
# Validation DataLoader 0:  51%|███████████████████████▏                      | 402/796 [00:20<00:20, 19.24it/s]
# Validation DataLoader 0:  51%|███████████████████████▎                      | 403/796 [00:20<00:20, 19.24it/s]
# Validation DataLoader 0:  51%|███████████████████████▎                      | 404/796 [00:20<00:20, 19.25it/s]
# Validation DataLoader 0:  51%|███████████████████████▍                      | 405/796 [00:21<00:20, 19.25it/s]
# Validation DataLoader 0:  51%|███████████████████████▍                      | 406/796 [00:21<00:20, 19.25it/s]
# Validation DataLoader 0:  51%|███████████████████████▌                      | 407/796 [00:21<00:20, 19.26it/s]
# Validation DataLoader 0:  51%|███████████████████████▌                      | 408/796 [00:21<00:20, 19.26it/s]
# Validation DataLoader 0:  51%|███████████████████████▋                      | 409/796 [00:21<00:20, 19.27it/s]
# ...
# Validation DataLoader 0:  82%|█████████████████████████████████████▊        | 654/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████▊        | 655/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  82%|█████████████████████████████████████▉        | 656/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  83%|█████████████████████████████████████▉        | 657/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████        | 658/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████        | 659/796 [00:33<00:07, 19.50it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████▏       | 660/796 [00:33<00:06, 19.51it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████▏       | 661/796 [00:33<00:06, 19.51it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████▎       | 662/796 [00:33<00:06, 19.51it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████▎       | 663/796 [00:33<00:06, 19.51it/s]
# Validation DataLoader 0:  83%|██████████████████████████████████████▎       | 664/796 [00:34<00:06, 19.51it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▍       | 665/796 [00:34<00:06, 19.51it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▍       | 666/796 [00:34<00:06, 19.51it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▌       | 667/796 [00:34<00:06, 19.52it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▌       | 668/796 [00:34<00:06, 19.52it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▋       | 669/796 [00:34<00:06, 19.52it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▋       | 670/796 [00:34<00:06, 19.52it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▊       | 671/796 [00:34<00:06, 19.52it/s]
# Validation DataLoader 0:  84%|██████████████████████████████████████▊       | 672/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|██████████████████████████████████████▉       | 673/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|██████████████████████████████████████▉       | 674/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████       | 675/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████       | 676/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████       | 677/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████▏      | 678/796 [00:34<00:06, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████▏      | 679/796 [00:34<00:05, 19.53it/s]
# Validation DataLoader 0:  85%|███████████████████████████████████████▎      | 680/796 [00:34<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▎      | 681/796 [00:34<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▍      | 682/796 [00:34<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▍      | 683/796 [00:34<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▌      | 684/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▌      | 685/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▋      | 686/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▋      | 687/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  86%|███████████████████████████████████████▊      | 688/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  87%|███████████████████████████████████████▊      | 689/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  87%|███████████████████████████████████████▊      | 690/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  87%|███████████████████████████████████████▉      | 691/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  87%|███████████████████████████████████████▉      | 692/796 [00:35<00:05, 19.54it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████      | 693/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████      | 694/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████▏     | 695/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  87%|████████████████████████████████████████▏     | 696/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▎     | 697/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▎     | 698/796 [00:35<00:05, 19.55it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▍     | 699/796 [00:35<00:04, 19.55it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▍     | 700/796 [00:35<00:04, 19.55it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▌     | 701/796 [00:35<00:04, 19.56it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▌     | 702/796 [00:35<00:04, 19.56it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▋     | 703/796 [00:35<00:04, 19.56it/s]
# Validation DataLoader 0:  88%|████████████████████████████████████████▋     | 704/796 [00:35<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▋     | 705/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▊     | 706/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▊     | 707/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▉     | 708/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|████████████████████████████████████████▉     | 709/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████     | 710/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████     | 711/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  89%|█████████████████████████████████████████▏    | 712/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▏    | 713/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▎    | 714/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▎    | 715/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▍    | 716/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▍    | 717/796 [00:36<00:04, 19.56it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▍    | 718/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▌    | 719/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  90%|█████████████████████████████████████████▌    | 720/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▋    | 721/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▋    | 722/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▊    | 723/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▊    | 724/796 [00:36<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▉    | 725/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|█████████████████████████████████████████▉    | 726/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████    | 727/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  91%|██████████████████████████████████████████    | 728/796 [00:37<00:03, 19.56it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▏   | 729/796 [00:37<00:03, 19.56it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▏   | 730/796 [00:37<00:03, 19.56it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▏   | 731/796 [00:37<00:03, 19.56it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▎   | 732/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▎   | 733/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▍   | 734/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▍   | 735/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  92%|██████████████████████████████████████████▌   | 736/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▌   | 737/796 [00:37<00:03, 19.57it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▋   | 738/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▋   | 739/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▊   | 740/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▊   | 741/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▉   | 742/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▉   | 743/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  93%|██████████████████████████████████████████▉   | 744/796 [00:37<00:02, 19.58it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████   | 745/796 [00:38<00:02, 19.58it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████   | 746/796 [00:38<00:02, 19.58it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▏  | 747/796 [00:38<00:02, 19.58it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▏  | 748/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▎  | 749/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▎  | 750/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▍  | 751/796 [00:38<00:02, 19.58it/s]
# Validation DataLoader 0:  94%|███████████████████████████████████████████▍  | 752/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▌  | 753/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▌  | 754/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▋  | 755/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▋  | 756/796 [00:38<00:02, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▋  | 757/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▊  | 758/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▊  | 759/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  95%|███████████████████████████████████████████▉  | 760/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|███████████████████████████████████████████▉  | 761/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████  | 762/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████  | 763/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████▏ | 764/796 [00:38<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████▏ | 765/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████▎ | 766/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████▎ | 767/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  96%|████████████████████████████████████████████▍ | 768/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▍ | 769/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▍ | 770/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▌ | 771/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▌ | 772/796 [00:39<00:01, 19.59it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▋ | 773/796 [00:39<00:01, 19.60it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▋ | 774/796 [00:39<00:01, 19.60it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▊ | 775/796 [00:39<00:01, 19.60it/s]
# Validation DataLoader 0:  97%|████████████████████████████████████████████▊ | 776/796 [00:39<00:01, 19.60it/s]
# Validation DataLoader 0:  98%|████████████████████████████████████████████▉ | 777/796 [00:39<00:00, 19.60it/s]
# Validation DataLoader 0:  98%|████████████████████████████████████████████▉ | 778/796 [00:39<00:00, 19.60it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████ | 779/796 [00:39<00:00, 19.60it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████ | 780/796 [00:39<00:00, 19.60it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████▏| 781/796 [00:39<00:00, 19.61it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████▏| 782/796 [00:39<00:00, 19.61it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████▏| 783/796 [00:39<00:00, 19.61it/s]
# Validation DataLoader 0:  98%|█████████████████████████████████████████████▎| 784/796 [00:39<00:00, 19.61it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▎| 785/796 [00:40<00:00, 19.61it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▍| 786/796 [00:40<00:00, 19.61it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▍| 787/796 [00:40<00:00, 19.61it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▌| 788/796 [00:40<00:00, 19.61it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▌| 789/796 [00:40<00:00, 19.62it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▋| 790/796 [00:40<00:00, 19.62it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▋| 791/796 [00:40<00:00, 19.62it/s]
# Validation DataLoader 0:  99%|█████████████████████████████████████████████▊| 792/796 [00:40<00:00, 19.63it/s]
# Validation DataLoader 0: 100%|█████████████████████████████████████████████▊| 793/796 [00:40<00:00, 19.63it/s]
# Validation DataLoader 0: 100%|█████████████████████████████████████████████▉| 794/796 [00:40<00:00, 19.64it/s]
# Validation DataLoader 0: 100%|█████████████████████████████████████████████▉| 795/796 [00:40<00:00, 19.64it/s]
# Validation DataLoader 0: 100%|██████████████████████████████████████████████| 796/796 [00:40<00:00, 19.65it/s]
# Epoch 6:  25%|▎| 1004/3992 [01:22<04:05, 12.18it/s, val_loss=1.470, val_iou=0.515, train_loss=0.826, train_iou

# %% [markdown]
# ## Cell 11 — Retrain winner on the full dataset
#
# The NAS search used only 8 000 tiles per candidate for speed.
# Here we take the winning architecture and retrain it properly:
#
# - **FP32 full training**: 50 epochs on all 50 822 train tiles
# - **FP16-aware finetune**: 15 epochs from the FP32 checkpoint
#
# This is the step that produces the final deployable models.

# %%
# full dataset datamodule (no NAS subset limit)
dm_full = BalancedTileDataModule(
    TILES_ROOT, INDEX_CSV,
    batch_size=BATCH_SIZE, num_workers=4,
    nas_subset_n=None,   # use ALL train tiles
)
dm_full.setup()
print(f"Full dataset — train: {len(dm_full.train_ds):,}  "
      f"val: {len(dm_full.val_ds):,}  test: {len(dm_full.test_ds):,}")

# inspect winner
winner = pop.population[0]
print(f"\nWinner architecture:")
print(f"  fitness  : {winner.fitness:.4f}")
print(f"  fp16 IoU : {winner.metric:.4f}")
print(f"  params   : {winner.model_size:,}  "
      f"({winner.model_size*2/1e6:.2f} MB at FP16)")
print(f"  layers   : {winner.parsed_layers}")

# retrain with higher epoch budgets
print("\nStarting full retraining...")
train_two_scenarios(
    pop, idx=0, dm=dm_full,
    lr=LR,
    fp32_epochs=50,   # full convergence budget
    fp16_epochs=15,   # FP16 fine-tune
)

final_dir = Path(SAVE_DIR) / f"generation_{pop.generation}" / "model_0"
print("\nFinal models saved:")
print(f"  FP32 (ground/GPU deployment) : {final_dir / 'model_fp32.pt'}")
print(f"  FP16 (Myriad X deployment)   : {final_dir / 'model_fp16aware.pt'}")

# %% [markdown]
# ## Cell 12 — Verify saved models
#
# Confirm both model files exist, load cleanly, and that the FP16 model
# fits within the 6 MB Myriad X target.

# %%
fp32_path = final_dir / "model_fp32.pt"
fp16_path = final_dir / "model_fp16aware.pt"

assert fp32_path.exists(), f"FP32 model not found: {fp32_path}"
assert fp16_path.exists(), f"FP16 model not found: {fp16_path}"

fp32_sd = torch.load(fp32_path, map_location="cpu")
fp16_sd = torch.load(fp16_path, map_location="cpu")

n_params  = sum(v.numel() for v in fp32_sd.values())
fp32_mb   = n_params * 4 / 1e6    # FP32 = 4 bytes/param
fp16_mb   = n_params * 2 / 1e6    # FP16 = 2 bytes/param

print(f"Parameters   : {n_params:,}")
print(f"FP32 size    : {fp32_mb:.2f} MB  (ground/GPU deployment)")
print(f"FP16 size    : {fp16_mb:.2f} MB  (Myriad X on-board deployment)")
print(f"6 MB target  : {'✓ PASS' if fp16_mb <= 6.0 else '✗ FAIL — architecture too large'}")

assert fp16_mb <= 6.5, \
    f"FP16 model exceeds 6 MB budget: {fp16_mb:.2f} MB — lower max_parameters in config.ini"

# load metrics JSON for a clean summary
metrics = json.load(open(final_dir / "metrics.json"))
print(f"\nFinal model performance (full dataset, NAS-search split):")
print(f"  FP32 IoU : {metrics['fp32_iou']:.4f}")
print(f"  FP16 IoU : {metrics['fp16_iou']:.4f}")
print(f"  FP16 loss: {metrics['fp32_iou'] - metrics['fp16_iou']:.4f}  "
      f"(quantisation gap — target <0.01)")

# %% [markdown]
# ## Cell 13 — Full search results summary
#
# Inspect every candidate across all generations.

# %%
all_metrics = []
for metrics_path in sorted(Path(SAVE_DIR).glob("generation_*/model_*/metrics.json")):
    try:
        m = json.load(open(metrics_path))
        all_metrics.append(m)
    except Exception:
        pass

results_df = pd.DataFrame(all_metrics).sort_values("fitness", ascending=False)
print(f"Total candidates evaluated: {len(results_df)}")
print(f"\nTop 10 by fitness:")
print(results_df[["gen","idx","params","fp32_iou","fp16_iou","fitness"]].head(10).to_string(index=False))

# save full results
results_df.to_csv(f"{SAVE_DIR}/nas_results_all.csv", index=False)
print(f"\nFull results saved to {SAVE_DIR}/nas_results_all.csv")
